# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
l = []
i = 7

while i != 1 :
    if (i % 2) == 0: #check if i is an even number
        i = i/2
    else:
        i = (3*i + 1)
    
    l.append(i)
    
plt.plot(l)
